# %%
import pandas as pd

news = pd.read_csv('news_naver.csv')
news
# Out:
#      Unnamed: 0        date  \
# 0             0  2017.12.28
# 1             1  2017.12.14
# 2             2  2017.12.07
# 3             3  2017.11.30
# 4             4  2017.11.09
# ..          ...         ...
# 260         260  2005.08.11
# 261         261  2005.07.07
# 262         262  2005.06.23
# 263         263  2005.06.09
# 264         264  2005.05.12
#
#                                               contents Polarity
# 0                                                   []        H
# 1                                                   []        H
# 2                                                   []        H
# 3    ['일부 위원은 최근 미국의 금융·경제상황을 보면 금년 12월 미 연준이 금리를  ...        H
# 4                                                   []        D
# ..                                                 ...      ...
# 260                                                 []        H
# 261                                                 []        D
# ...

# %%
text = news['contents']
text_df = pd.DataFrame(news['contents'])
date_df = pd.DataFrame(news['date'])
text_date_df = pd.concat([text, date], axis=1)
text[3] # 뉴스 문서
# Out:
# "['일부 위원은 최근 미국의 금융·경제상황을 보면 금년 12월 미 연준이 금리를  인상할 것으로 예견되고 실물경기도 견조한 회복세를 지속하고 있음에도 불구하  고 수익률곡선은 계속 평탄화되고 있다고 지적하였음.', '일각에서는 미국의 장기실  질균형금리 및 기대인플레이션의 하락을 그 원인으로 거론하고 있지만 이 같은  요인은 이미 이전부터 장기금리에 반영되어 왔으므로 최근의 수익률곡선 변화를  설명하는 데에 한계가 있는 것으로 보인다고 언급하였음.', '한편 이러한 현상을 향  후 실물경기의 침체 우려와 글로벌 장기채권 수요의 유입에 따른 결과로 해석하  는 시각도 있다고 소개하고, 이에 대한 관련부서의 견해를 물었음.', '이에 대해 관련부서에서는 수익률곡선의 평탄화나 장단기금리차의 역전이 장  기금리의 하락에 의해 주도되는 경우에는 향후 실물경기의 침체를 예고하는 신호  (signal)로 받아들여질 수 있겠지만, 최근 미국의 수익률곡선 평탄화는 주로 재무  부의 단기채권 발행 확대 방침, 미 연준의 금리인상 기대 등으로 단기금리가 크  게 상승한 데에 따른 것으로 보인다고 답변하였음.', '이에 동 위원은 미국의 세제개편안이 의회를 통과한다면 수익률곡선이나 정  책금리 경로가 가팔라질 가능성은 없는지 관련부서의 견해를 물었으며,  이에 대해 관련부서에서는 이번 세제개편안이 법인세율 인하 등 대규모 감세  안을 골자로 하고 있는 만큼 미 금융시장 지표가 동 법안의 처리 관측에 따라 등  락하는 양상을 보이고 있다고 설명하였음.', '비록 일부 선반영된 측면도 있겠지만  미 의회에서 세제개편안을 가결한다면 재정적자 보전을 위한 장기국채의 발행 전  망이 부각되면서 수익률곡선이 가팔라질 가능성도 있을 것으로 생각된다고 답변  - 9 -  \\x0c이와 관련하여 동 위원은 한·미 간 장기금리의 동조화 경향에도 불구하고 우  리나라의 수익률곡선이 미국과 달리 가팔라지고 있는 이유는 무엇인지 관련부서  의 견해를 물었으며,  이에 대해 관련부서에서는 과거 장기금
# ...

# %%
# 모듈 모음
import pandas as pd
from ekonlpy.tag import Mecab
from ekonlpy.sentiment import MPCK
from tqdm.notebook import tqdm
import re

mecab = Mecab()

# %%
ls_text = list(text)
ls_text[n] # 리스트를 씌워 준 n번째 뉴스문서.
# Out:
# "['일부 위원은 최근 미국의 금융·경제상황을 보면 금년 12월 미 연준이 금리를  인상할 것으로 예견되고 실물경기도 견조한 회복세를 지속하고 있음에도 불구하  고 수익률곡선은 계속 평탄화되고 있다고 지적하였음.', '일각에서는 미국의 장기실  질균형금리 및 기대인플레이션의 하락을 그 원인으로 거론하고 있지만 이 같은  요인은 이미 이전부터 장기금리에 반영되어 왔으므로 최근의 수익률곡선 변화를  설명하는 데에 한계가 있는 것으로 보인다고 언급하였음.', '한편 이러한 현상을 향  후 실물경기의 침체 우려와 글로벌 장기채권 수요의 유입에 따른 결과로 해석하  는 시각도 있다고 소개하고, 이에 대한 관련부서의 견해를 물었음.', '이에 대해 관련부서에서는 수익률곡선의 평탄화나 장단기금리차의 역전이 장  기금리의 하락에 의해 주도되는 경우에는 향후 실물경기의 침체를 예고하는 신호  (signal)로 받아들여질 수 있겠지만, 최근 미국의 수익률곡선 평탄화는 주로 재무  부의 단기채권 발행 확대 방침, 미 연준의 금리인상 기대 등으로 단기금리가 크  게 상승한 데에 따른 것으로 보인다고 답변하였음.', '이에 동 위원은 미국의 세제개편안이 의회를 통과한다면 수익률곡선이나 정  책금리 경로가 가팔라질 가능성은 없는지 관련부서의 견해를 물었으며,  이에 대해 관련부서에서는 이번 세제개편안이 법인세율 인하 등 대규모 감세  안을 골자로 하고 있는 만큼 미 금융시장 지표가 동 법안의 처리 관측에 따라 등  락하는 양상을 보이고 있다고 설명하였음.', '비록 일부 선반영된 측면도 있겠지만  미 의회에서 세제개편안을 가결한다면 재정적자 보전을 위한 장기국채의 발행 전  망이 부각되면서 수익률곡선이 가팔라질 가능성도 있을 것으로 생각된다고 답변  - 9 -  \\x0c이와 관련하여 동 위원은 한·미 간 장기금리의 동조화 경향에도 불구하고 우  리나라의 수익률곡선이 미국과 달리 가팔라지고 있는 이유는 무엇인지 관련부서  의 견해를 물었으며,  이에 대해 관련부서에서는 과거 장기금
# ...

# %%
ls_txt_sen = [ls_txt.split('.') for ls_txt in tqdm(ls_text)]
ls_txt_sen[3]
# Out:
# ...
# ["['일부 위원은 최근 미국의 금융·경제상황을 보면 금년 12월 미 연준이 금리를  인상할 것으로 예견되고 실물경기도 견조한 회복세를 지속하고 있음에도 불구하  고 수익률곡선은 계속 평탄화되고 있다고 지적하였음",
#  "', '일각에서는 미국의 장기실  질균형금리 및 기대인플레이션의 하락을 그 원인으로 거론하고 있지만 이 같은  요인은 이미 이전부터 장기금리에 반영되어 왔으므로 최근의 수익률곡선 변화를  설명하는 데에 한계가 있는 것으로 보인다고 언급하였음",
#  "', '한편 이러한 현상을 향  후 실물경기의 침체 우려와 글로벌 장기채권 수요의 유입에 따른 결과로 해석하  는 시각도 있다고 소개하고, 이에 대한 관련부서의 견해를 물었음",
#  "', '이에 대해 관련부서에서는 수익률곡선의 평탄화나 장단기금리차의 역전이 장  기금리의 하락에 의해 주도되는 경우에는 향후 실물경기의 침체를 예고하는 신호  (signal)로 받아들여질 수 있겠지만, 최근 미국의 수익률곡선 평탄화는 주로 재무  부의 단기채권 발행 확대 방침, 미 연준의 금리인상 기대 등으로 단기금리가 크  게 상승한 데에 따른 것으로 보인다고 답변하였음",
#  "', '이에 동 위원은 미국의 세제개편안이 의회를 통과한다면 수익률곡선이나 정  책금리 경로가 가팔라질 가능성은 없는지 관련부서의 견해를 물었으며,  이에 대해 관련부서에서는 이번 세제개편안이 법인세율 인하 등 대규모 감세  안을 골자로 하고 있는 만큼 미 금융시장 지표가 동 법안의 처리 관측에 따라 등  락하는 양상을 보이고 있다고 설명하였음",
# ...

# %%
len(ls_txt_sen) # 의사록 265개
len(ls_txt_sen[3]) # 3번째 의사록의 문장은 35개. 그리고 빈 리스트는 값이 1로 나온다.
# Out:
# 35

# %%
ls_txt_sen[3][0] # 3번째 의사록의 첫 번째 문장

for ls_txt_ in tqdm(ls_txt_sen): # ls_txt_ : 의사록
    for ls_ in ls_txt_: # ls_ 의사록의 문장
        print(len(ls_txt_))
# Out:
# ...
# 1
# 1
# 1
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 1
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 1
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# 1
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 1
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 1
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# ...

# %% [markdown]
# (최근)이건 실험인데,
# test1 = txt_[3][0]
#  : ["['일부 위원은 최근 미국의 금융·경제상황을 보면 금년 12월 미 연준이 금리를  인상할 것으로 예견되고 실물경기도 견조한 회복세를 지속하고 있음에도 불구하  고 수익률곡선은 계속 평탄화되고 있다고 지적하였음"
#
# test_txt = []
# test_ngram = []
#
# mpck = MPCK()
# tokens_ = mpck.tokenize(test1)
# test_txt.append(tokens_)
# ngrams_ = mpck.ngramize(tokens_)
# test_ngram.append(ngrams_)
#
# len(test_txt[0])
# 즉, 문장 하나의 token(unigram)은 19개가 나왔다는 뜻.
# 그리고 아래에서 보겠지만, n_gram은 2개가 나왔다.

# %% [markdown]
# (최근)test2 = txt_[3][1]
#
# test2_txt = []
# test2_ngram = []
#
# mpck = MPCK()
# tokens_ = mpck.tokenize(test2)
# test2_txt.append(tokens_)
# ngrams_ = mpck.ngramize(tokens_)
# test2_ngram.append(ngrams_)
#
# test2_txt
#
# 난관에 봉착했는데, 몇 번째 의사록이라는 개념이 없어지고, 모든 의사록을 모두 문장으로 나누고 token, n_gram화 시켜줬다는 것을 알 수 있다.
# 인덱스를 유지한 채, 문서를 문장으로 나누고, token / n_gram을 모두 같은 인덱스로 넣는 방법은 없을까....?

# %%
txt_[3][0]
# Out:
# "['일부 위원은 최근 미국의 금융·경제상황을 보면 금년 12월 미 연준이 금리를  인상할 것으로 예견되고 실물경기도 견조한 회복세를 지속하고 있음에도 불구하  고 수익률곡선은 계속 평탄화되고 있다고 지적하였음"

# %%
'''
(여기부터는 위의 2개 notebook(test1, test2)과 무관함)
예시로 위와 같이 txt_[3][0]는 3번째 의사록 문서의 1번째 문장이다.
mpck를 사용하면, 자동으로 전처리가 되므로(5개 형태소만 추출) 따로 re는 사용하지 않았다.
그래서 2중 for문을 사용하여, txt_[i][j]에서 유니그램(토큰)과 ngram을 추출하여 따로 담아 준 다음
txt_gram(unigram=token)과 n_gram(bi-gram 이상)을 합칠 것이다(어짜피 행 수는 같으므로 axis=1을 이용).
 - txt_ : 모든 의사록
 - txt_[i] : i번째 의사록 == tt
 - txt_[i][j] : i번째 의사록의 j째 문장 == t
'''

n_gram = []
txt_gram = []

for tt in tqdm(txt_):
    for t in tt:
        mpck = MPCK()
        tokens = mpck.tokenize(t)
        txt_gram.append(tokens)
        ngrams = mpck.ngramize(tokens)
        n_gram.append(ngrams)

print(txt_gram)
print(n_gram)
# Out:
# ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
'''
각각 txt_gram과 n_gram의 갯수는 동일하다.
그리고 3번째 의사록의 1번째 문장에서는 총 19개의 유니그램이 나왔다.
동일하게 3번째 의사록의 1번째 문장의 n_gram의 갯수는 2개가 나왔다.
'''
len(txt_gram[3]), len(n_gram[3])
# Out:
# (19, 2)

# %%
'''
이제 여기서 해야할 것은,
문서에서 문장 단위로 토큰과 n_gram화 시켰으므로,
이것을 콜금리와 합쳐주는 것이다(사전구축).
우선 규호형이 만들어준 콜금리 기준(H / D)을 의사록과 합친다.
'''

Callrate_labeling = pd.read_csv('Callrate_labeling.csv')
calltext = text_date.merge(Callrate_labeling, on='date')
calltext
# Out:
#                                               contents        date Polarity
# 0                                                   []  2017.12.28        H
# 1                                                   []  2017.12.14        H
# 2                                                   []  2017.12.07        H
# 3    ['일부 위원은 최근 미국의 금융·경제상황을 보면 금년 12월 미 연준이 금리를  ...  2017.11.30        H
# 4                                                   []  2017.11.09        D
# ..                                                 ...         ...      ...
# 260                                                 []  2005.08.11        H
# 261                                                 []  2005.07.07        D
# 262                                                 []  2005.06.23        D
# 263                                                 []  2005.06.09        D
# 264  ['일부 위원은 내외금리차 역전에 따라  자금의 해외유출이 대규모로 발생될 가능성을...  2005.05.12        H
#
# [265 rows x 3 columns]

# %%
'''
그리고 pd.calltext와 토큰/그램(token + n_gram)을 합친다.
'''

# %%
txt_df = pd.DataFrame(txt_gram)
ngram_df = pd.DataFrame(n_gram)

# %%
# txt_df[3:4][18] 이건 3번째 의사록의 19번째 token이다(이게 마지막이고, [19]는 None).
txt_df
# Out:
#              0       1        2         3        4          5       6    \
# 0           None    None     None      None     None       None    None
# 1           None    None     None      None     None       None    None
# 2           None    None     None      None     None       None    None
# 3       금융경제/NNG    보/VV  fed/NNG    금리/NNG   인상/NNG       하/VV  예견/NNG
# 4         일각/NNG   장/NNG   기실/NNG  균형금리/NNG   기대/NNG  인플레이션/NNG  하락/NNG
# ...          ...     ...      ...       ...      ...        ...     ...
# 17746       None    None     None      None     None       None    None
# 17747       None    None     None      None     None       None    None
# 17748       낮/VA  수준/NNG   유지/NNG     하/XSV     None       None    None
# 17749  신용카드사/NNG  자금/NNG   조달/NNG    여건/NNG  카드채/NNG     발행/NNG    늘/VV
# 17750       None    None     None      None     None       None    None
#
#            7         8       9    ...   198   199   200   201   202   203  \
# ...
